# %% [markdown]
# <a href="https://colab.research.google.com/github/Relator784/ai-healthcare-learning/blob/main/01_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, AI Healthcare")
# Out:
# Hello, AI Healthcare
